# %%
#pip install gTTS

# %%
from gtts import gTTS
mytext="fama "
output=gTTS(text=mytext, lang='en', slow=False)
output.save('mrb.mp3')

# %%
from IPython.display import Audio
audio=Audio(filename='mrb.mp3')

# %%
audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from gtts import gTTS
yazi="everything will be fine"
output=gTTS(text=yazi, lang='en', slow=False)
output.save('evrythng.mp3')

# %%
from IPython.display import Audio
audio=Audio(filename='evrythng.mp3')

# %%
audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from gtts import gTTS
yazi="merhabaaaaa"
output=gTTS(text=yazi, lang='tr', slow=False)
output.save('hayirli_olsun.mp3')

# %%
from IPython.display import Audio
audio=Audio(filename='hayirli_olsun.mp3')

# %%
audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
